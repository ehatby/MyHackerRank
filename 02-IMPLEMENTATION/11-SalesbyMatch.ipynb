# %% [markdown]
# ----
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# ----

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'sockMerchant' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY ar
#

# %%
def sockMerchant(n, ar):
    # Write your code here
    pairs = 0
    unique = []
    for i in ar:
        if i not in unique:
            unique.append(i)

    for j in unique:
        pairs += int(ar.count(j)/2)
    return pairs

# %%
if __name__ == '__main__':

    n = int(input().strip())

    ar = list(map(int, input().rstrip().split()))

    result = sockMerchant(n, ar)

    print('result:', result)
# Out:
# 9
# 10 20 20 10 10 30 50 10 20
# result: 3

# %%
# veya 
"""
k = 0
sayac =0
ar.sort()
while k < n:
    if ar.count(ar[k]) > 1:
        sayac += int(ar.count(ar[k]) / 2)
        k += ar.count(ar[k])
    else:
        k +=1
sayac
"""
# Out:
# '\nk = 0\nsayac =0\nar.sort()\nwhile k < n:\n    if ar.count(ar[k]) > 1:\n        sayac += int(ar.count(ar[k]) / 2)\n        k += ar.count(ar[k])\n    else:\n        k +=1\nsayac\n'
